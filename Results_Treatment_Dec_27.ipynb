# %% [markdown]
# ## ADNI

# %%
import pandas as pd
result_adni=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\ADNI\\ADNI-results\\ADNI_probability_abeta.csv")

# %%
df=result_adni

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score

# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')

# Step 1: Rename the columns to remove the "Abeta-" prefix
df.rename(columns={
    'Abeta-Clearly positive': 'Clearly positive',
    'Abeta-Weakly positive': 'Weakly positive',
    'Abeta-Intermediate negative': 'Intermediate negative',
    'Abeta-Negative': 'Negative'
}, inplace=True)

# Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Clearly positive', 'Weakly positive', 'Intermediate negative', 'Negative']].idxmax(axis=1)

# %%
adni_result_abeta=df

# %%
adni_result_abeta
# Out:
#       Index  Clearly positive  Weakly positive  Intermediate negative  \
# 0         0          0.000000         0.000000               0.000000
# 1         1          0.000000         0.000000               0.000000
# 2         2          0.000000         0.000000               0.000000
# 3         3          0.000000         0.000000               0.000000
# 4         4          0.000000         0.000000               0.000000
# ...     ...               ...              ...                    ...
# 2459   2459          0.017942         0.014417               0.061653
# 2460   2460          0.229924         0.094360               0.165608
# 2461   2461          0.394677         0.102958               0.159464
# 2462   2462          0.000000         0.000000               0.000000
# 2463   2463          0.000000         0.000000               0.000000
#
#       Negative             Truth        Prediction
# 0     0.000000          Unknown.  Clearly positive
# 1     0.000000          Unknown.  Clearly positive
# 2     0.000000          Unknown.  Clearly positive
# 3     0.000000          Unknown.  Clearly positive
# 4     0.000000          Unknown.  Clearly positive
# ...        ...               ...               ...
# 2459  0.905988          Negative          Negative
# 2460  0.510108          Negative          Negative
# 2461  0.342901  Clearly positive  Clearly positive
# 2462  0.000000          Unknown.  Clearly positive
# 2463  0.000000          Unknown.  Clearly positive
#
# [2464 rows x 7 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
result_adni=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\ADNI\\ADNI-results\\ADNI_probability_meta_tau.csv")


# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')
df=result_adni
# Step 1: Rename the columns to remove the "Abeta-" prefixAbeta-Slow	Abeta-Moderate	Abeta-Fast	Abeta-Not decreasing

df.rename(columns={
    'Meta Tau-Low': 'Low',
    'Meta Tau-Very low': 'Very low',
    'Meta Tau-Super high': 'Super high',
    'Meta Tau-High':'High'
}, inplace=True)

# # Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Very low', 'Low',  'High','Super high']].idxmax(axis=1)

# %%
adni_result_meta=df

# %%
adni_result_abeta
# Out:
#       Index  Clearly positive  Weakly positive  Intermediate negative  \
# 0         0          0.000000         0.000000               0.000000
# 1         1          0.000000         0.000000               0.000000
# 2         2          0.000000         0.000000               0.000000
# 3         3          0.000000         0.000000               0.000000
# 4         4          0.000000         0.000000               0.000000
# ...     ...               ...              ...                    ...
# 2459   2459          0.017942         0.014417               0.061653
# 2460   2460          0.229924         0.094360               0.165608
# 2461   2461          0.394677         0.102958               0.159464
# 2462   2462          0.000000         0.000000               0.000000
# 2463   2463          0.000000         0.000000               0.000000
#
#       Negative             Truth        Prediction
# 0     0.000000          Unknown.  Clearly positive
# 1     0.000000          Unknown.  Clearly positive
# 2     0.000000          Unknown.  Clearly positive
# 3     0.000000          Unknown.  Clearly positive
# 4     0.000000          Unknown.  Clearly positive
# ...        ...               ...               ...
# 2459  0.905988          Negative          Negative
# 2460  0.510108          Negative          Negative
# 2461  0.342901  Clearly positive  Clearly positive
# 2462  0.000000          Unknown.  Clearly positive
# 2463  0.000000          Unknown.  Clearly positive
#
# [2464 rows x 7 columns]

# %%
combined_prediction=pd.merge(adni_result_abeta,adni_result_meta, on=["Index"],how="left")

# %%
combined_prediction_subset=combined_prediction[(combined_prediction["Truth_x"]!="Unknown.")&(combined_prediction["Truth_y"]!="Unknown.")]

# %%
combined_prediction_subset.to_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\ADNI\\ADNI-results\\ADNI_treatment.csv",index=False)

# %% [markdown]
# ## HABS-HD

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
result_habs=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\HABS-HD\\HABS-HD-results\\HABS_probability_meta_tau.csv")


# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')
df=result_habs
# Step 1: Rename the columns to remove the "Abeta-" prefixAbeta-Slow	Abeta-Moderate	Abeta-Fast	Abeta-Not decreasing

df.rename(columns={
    'Meta Tau-Low': 'Low',
    'Meta Tau-Very low': 'Very low',
    'Meta Tau-Super high': 'Super high',
    'Meta Tau-High':'High'
}, inplace=True)

# # Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Very low', 'Low',  'High','Super high']].idxmax(axis=1)

# %%
habs_result_meta=df

# %%
import pandas as pd
result_habs=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\HABS-HD\\HABS-HD-results\\HABS_probability_abeta.csv")
df=result_habs
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score

# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')

# Step 1: Rename the columns to remove the "Abeta-" prefix
df.rename(columns={
    'Abeta-Clearly positive': 'Clearly positive',
    'Abeta-Weakly positive': 'Weakly positive',
    'Abeta-Intermediate negative': 'Intermediate negative',
    'Abeta-Negative': 'Negative'
}, inplace=True)

# Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Clearly positive', 'Weakly positive', 'Intermediate negative', 'Negative']].idxmax(axis=1)

habs_result_abeta=df

# %%
combined_prediction=pd.merge(habs_result_abeta,habs_result_meta, on=["Index"],how="left")

# %%
combined_prediction_subset=combined_prediction[(combined_prediction["Truth_x"]!="Unknown.")&(combined_prediction["Truth_y"]!="Unknown.")]

# %%
combined_prediction_subset.to_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\HABS-HD\\HABS-HD-results\\HABS_treatment.csv",index=False)

# %% [markdown]
# ## POINTER

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
result_pointer=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\POINTER\\POINTER-results\\POINTER_probability_abeta.csv")


# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')
df=result_pointer
# Step 1: Rename the columns to remove the "Abeta-" prefixAbeta-Slow	Abeta-Moderate	Abeta-Fast	Abeta-Not decreasing
# Step 1: Rename the columns to remove the "Abeta-" prefix
df.rename(columns={
    'Abeta-Clearly positive': 'Clearly positive',
    'Abeta-Weakly positive': 'Weakly positive',
    'Abeta-Intermediate negative': 'Intermediate negative',
    'Abeta-Negative': 'Negative'
}, inplace=True)

# Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Clearly positive', 'Weakly positive', 'Intermediate negative', 'Negative']].idxmax(axis=1)

pointer_result_abeta=df

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
result_pointer=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\POINTER\\POINTER-results\\POINTER_probability_meta_tau.csv")


# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')
df=result_pointer
# Step 1: Rename the columns to remove the "Abeta-" prefixAbeta-Slow	Abeta-Moderate	Abeta-Fast	Abeta-Not decreasing

df.rename(columns={
    'Meta Tau-Low': 'Low',
    'Meta Tau-Very low': 'Very low',
    'Meta Tau-Super high': 'Super high',
    'Meta Tau-High':'High'
}, inplace=True)

# # Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Very low', 'Low',  'High','Super high']].idxmax(axis=1)

pointer_result_meta=df

# %%
combined_prediction=pd.merge(pointer_result_abeta,pointer_result_meta, on=["Index"],how="left")
combined_prediction_subset=combined_prediction[(combined_prediction["Truth_x"]!="Unknown.")&(combined_prediction["Truth_y"]!="Unknown.")]

# %%
combined_prediction_subset.to_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\POINTER\\POINTER-results\\POINTER_treatment.csv",index=False)

# %% [markdown]
# ## A4

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
result_A4=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\A4\\A4-results\\A4_probability_abeta.csv")


# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')
df=result_A4
# Step 1: Rename the columns to remove the "Abeta-" prefixAbeta-Slow	Abeta-Moderate	Abeta-Fast	Abeta-Not decreasing
# Step 1: Rename the columns to remove the "Abeta-" prefix
df.rename(columns={
    'Abeta-Clearly positive': 'Clearly positive',
    'Abeta-Weakly positive': 'Weakly positive',
    'Abeta-Intermediate negative': 'Intermediate negative',
    'Abeta-Negative': 'Negative'
}, inplace=True)

# Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Clearly positive', 'Weakly positive', 'Intermediate negative', 'Negative']].idxmax(axis=1)

A4_result_abeta=df

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score
result_A4=pd.read_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\A4\\A4-results\\A4_probability_meta_tau.csv")


# Assuming you have loaded your dataset in df
# df = pd.read_csv('your_dataset.csv')
df=result_A4
# Step 1: Rename the columns to remove the "Abeta-" prefixAbeta-Slow	Abeta-Moderate	Abeta-Fast	Abeta-Not decreasing

df.rename(columns={
    'Meta Tau-Low': 'Low',
    'Meta Tau-Very low': 'Very low',
    'Meta Tau-Super high': 'Super high',
    'Meta Tau-High':'High'
}, inplace=True)

# # Step 2: Generate 'Prediction' column based on max probability
df['Prediction'] = df[['Very low', 'Low',  'High','Super high']].idxmax(axis=1)

A4_result_meta=df

# %%
combined_prediction=pd.merge(A4_result_abeta,A4_result_meta, on=["Index"],how="left")
combined_prediction_subset=combined_prediction[(combined_prediction["Truth_x"]!="Unknown.")&(combined_prediction["Truth_y"]!="Unknown.")]

# %%
combined_prediction_subset.to_csv("D:\\Research\\AD\\ADLLM\\ADNI process 9\\A4\\A4-results\\A4_treatment.csv",index=False)
